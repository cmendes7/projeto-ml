# %%
print(1)
# Out:
# 1

# %%
import pandas as pd
df = pd.read_csv("hectare_terreno.csv")
df
# Out:
#     hectare   preco
# 0       1.0   33480
# 1       NaN   41850
# 2      30.0   50220
# 3      33.0   55242
# 4      40.0   66960
# 5      50.0   83700
# 6      67.0  112158
# 7      80.0  133920
# 8     111.0  185814
# 9     150.0  251100
# 10    201.0  336474

# %%
df.plot(kind="scatter", x="hectare", y="preco");

# %%
from sklearn import linear_model
modelo = linear_model.LinearRegression()
x = df[["hectare"]]
y = df[["preco"]]

modelo.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 6
#       3 x = df[["hectare"]]
#       4 y = df[["preco"]]
# ----> 6 modelo.fit(x, y)
#
# File c:\Users\folha\AppData\Local\pypoetry\Cache\virtualenvs\projeto-ml-z7_6L28Z-py3.12\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\folha\AppData\Local\pypoetry\Cache\virtualenvs\projeto-ml-z7_6L28Z-py3.12\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
# ...

# %%
print(modelo.predict([[200]])[0][0])
# Out:
# 334800.0000000001
# c:\Users\folha\AppData\Local\pypoetry\Cache\virtualenvs\projeto-ml-z7_6L28Z-py3.12\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
